# %%
import numpy as np

phi = np.linspace(0, 2 * np.pi, 120)

# %%
# !python3 -m Raster -s scenecharizard -o "charizard" -n 2
# Out:
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([ 0., 10., 40.], device='cuda:0'), look_at=tensor([ 0., 10.,  0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Gerando raios...
# Calculando interseções (Hit)...
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'charizard.png'

# %%
# !python3 -m Raster -s scenebunny -o "bunnymaldito.png" -n 10
# Out:
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Gerando raios...
# Calculando interseções (Hit)...
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunnymaldito.png.png'

# %%
for i in range(len(phi)):
    # !python3 -m Raster -s scenebunny -o "bunny/{i}bunny" -p {phi[i]}
# Out:
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/0bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/1bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/2bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/3bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/4bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/5bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/6bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/7bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/8bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/9bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/10bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/11bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/12bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/13bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/14bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/15bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/16bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/17bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/18bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/19bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/20bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/21bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/22bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/23bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/24bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/25bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/26bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/27bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/28bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/29bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/30bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/31bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/32bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/33bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/34bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/35bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/36bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/37bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/38bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/39bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/40bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/41bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/42bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/43bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/44bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/45bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/46bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/47bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/48bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/49bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/50bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/51bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# ...
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/102bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/103bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/104bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/105bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/106bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/107bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/108bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/109bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/110bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/111bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/112bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/113bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/114bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/115bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/116bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/117bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/118bunny.png'
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([0.0000, 0.5000, 0.2000], device='cuda:0'), look_at=tensor([0., 0., 0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Calculando cores e iluminação...
# /mnt/storage_C1/IRA/RayTracing/Base/Material.py:30: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cam_eye_tensor = torch.tensor(scene.camera.eye, device=device, dtype=torch.float32)
# Processando a imagem final...
# Renderização concluída com sucesso! Imagem salva como 'bunny/119bunny.png'
