# %%
from ObjTotri import *

# %%
ObjToTri("../RayTracing/bunny.obj")
# Out:
# [((-0.08656194, 0.14249188, 0.00843268),
#   (-0.08969839, 0.13971257, 0.01377476),
#   (-0.08949102, 0.14392581, 0.01248849)),
#  ((-0.08636751, 0.10906537, 0.01198064),
#   (-0.08591138, 0.10968787, 0.00765824),
#   (-0.0870559, 0.10562761, 0.00976511)),
#  ((-0.02630372, 0.12518875, 0.01739298),
#   (-0.02738318, 0.12324257, 0.02165886),
#   (-0.02585131, 0.12182948, 0.02607967)),
#  ((-0.07277722, 0.17854465, -0.0482088),
#   (-0.07208378, 0.17499844, -0.04193032),
#   (-0.06773818, 0.17728865, -0.05037596)),
#  ((-0.02585131, 0.12182948, 0.02607967),
#   (-0.03135885, 0.12140977, 0.02597109),
#   (-0.02859602, 0.11901156, 0.02988817)),
#  ((-0.06090236, 0.0434295, 0.04267853),
#   (-0.056901, 0.045437, 0.04323696),
#   (-0.06038127, 0.04592142, 0.04008874)),
#  ((-0.00179768, 0.13117283, 0.01636066),
#   (-0.00808407, 0.13030537, 0.01687228),
#   (-0.00341018, 0.13031957, 0.02175437)),
#  ((-0.05601079, 0.15381662, 0.02536928),
#   (-0.05662762, 0.15270606, 0.02962903),
# ...

# %%
ObjToTri("bunny.obj")
# Out:
# ...
#  ...]

# %%
import torch
import gc


def reset_gpu_memory():
    # 1. Deleta variáveis que podem estar segurando referências
    gc.collect()

    # 2. Limpa o cache de memória não utilizada que o PyTorch reserva na GPU
    torch.cuda.empty_cache()

    # 3. (Opcional) Reseta as estatísticas de pico para monitoramento limpo
    torch.cuda.reset_peak_memory_stats()

# %%
# !python3 -m Raster -s scenecharizard -o "charizard" -n 1
# Out:
# Renderizando usando: cuda
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Câmera original: Camera(eye=tensor([ 0., 10., 40.], device='cuda:0'), look_at=tensor([ 0., 10.,  0.], device='cuda:0'), up=tensor([ 0., -1.,  0.], device='cuda:0'), fov=45, img_width=800, img_height=600)
# Tipo do eye: <class 'torch.Tensor'>
# Tipo do look_at: <class 'torch.Tensor'>
# Gerando raios...
# Calculando interseções (Hit)...
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/mnt/storage_C1/IRA/RayTracing/Raster.py", line 142, in <module>
#     main(args)
#   File "/mnt/storage_C1/IRA/RayTracing/Raster.py", line 95, in main
#     hit_rec = scene.hit(rays)
#   File "/mnt/storage_C1/IRA/RayTracing/scenecharizard.py", line 97, in hit
# ...

# %%
# !python3 -m Raster -s scenebunny -o "trste"
# Out:
# Python was not found; run without arguments to install from the Microsoft Store, or disable this shortcut from Settings > Apps > Advanced app settings > App execution aliases.

# %%
import numpy as np

phi = np.linspace(0, 2 * np.pi, 120)

# %%
for i in range(len(phi)):
    # !python3 -m Raster -s scenebunny -o "bunny/{i}bunny" -p {phi[i]}
# Out:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/mnt/storage_C1/IRA/RayTracing/Raster.py", line 137, in <module>
#     main(args)
#   File "/mnt/storage_C1/IRA/RayTracing/Raster.py", line 61, in main
#     scene_module = importlib.import_module(args.scene)
#   File "/usr/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
# ...
